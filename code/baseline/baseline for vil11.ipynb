# %% [markdown]
# # Libraries

# %%
# importing libraries
import networkx as nx
import numpy as np
import matplotlib.pyplot as plt
import pickle
import random
import pandas as pd

# %% [markdown]
# # Mounting Drive

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# # Dataset Reading

# %%
data_vil2 = pd.read_csv("/content/drive/MyDrive/Project/vil11.csv")
data_vil2.drop("Unnamed: 0",axis=1,inplace=True)
data_vil2
# Out:
#       level_0  level_1
# 0           0        1
# 1           0        2
# 2           0       31
# 3           1        0
# 4           1        2
# ...       ...      ...
# 4682      603      602
# 4683      603      604
# 4684      604      601
# 4685      604      602
# 4686      604      603
#
# [4687 rows x 2 columns]

# %% [markdown]
# # Helper Functions

# %%
# -----------------------------------
# function to create graph
# -----------------------------------
def create_graph(dataset):

  # empty directed graph Gc
  Gc = nx.DiGraph()

  # populating graph
  for i,j in zip(dataset["level_0"],dataset["level_1"]):
      Gc.add_edge(i,j)
  
  # return graph
  return Gc


# -----------------------------------
# function to set status of all nodes of G to "inactive"
# -----------------------------------
def set_status_inactive(G):
    for i in G.nodes():
        G.nodes[i]['status'] = "inactive"

# -----------------------------------
# function to set status of list of nodes to active
# -----------------------------------
def set_status_active(G,l):
    for i in l:
        G.nodes[i]['status'] = "active"


# -----------------------------------
# function to set threshold of the nodes
# -----------------------------------
def set_threshold(G):
    random.seed(1)
    x = [random.uniform(0,1) for i in range(G.number_of_nodes())]
    for i,j in zip(G.nodes(),x):
        G.nodes[i]['threshold'] = j


# -----------------------------------
# function to set node influence
# -----------------------------------
def active_only(Gc,v):
    node_influence = 0
    status = Gc.nodes[v]["status"]
    if status == "active":
        node_influence = 1
    return node_influence

# -----------------------------------
# function to define aggregated influence on node u
# -----------------------------------
def peer_influence(Gc,u):
    
    count = 0
    pi = 0
    for v in Gc.predecessors(u):
        count += 1
        pi += (1 * active_only(Gc,v))
        
    if count != 0:
        pi = pi / count
    else:
        pi = 0
    
    return pi


# -----------------------------------
# function to calculate number of active nodes
# -----------------------------------
def count_active(G):
    count = 0
    for i in G.nodes():
       if G.nodes[i]["status"] == "active":
            count += 1
    return count


# -----------------------------------
# function to select set of p nodes of Gc as seed nodes based on some centrality
# -----------------------------------
def Centrality(Gc,p,centrality_measure):
        if centrality_measure == "degree":
            pr = nx.degree_centrality(Gc)
        elif centrality_measure == "closeness":
            pr = nx.closeness_centrality(Gc)
        elif centrality_measure == "betweeness":
            pr = nx.betweenness_centrality(Gc)
        elif centrality_measure == "pagerank":
            pr = nx.pagerank(Gc)
        elif centrality_measure == "katz":
            pr = nx.katz_centrality(Gc, 0.07,max_iter=50000)
        n = Gc.number_of_nodes()
        n = p
        pr = {k: v for k, v in sorted(pr.items(), key=lambda item: item[1],reverse=True)}
        return list(pr.keys())[:n]

# -----------------------------------
# general threshold model for cascade
# -----------------------------------
def gt_model(Gc,p=5,imax=7,centrality_measure="pagerank"):
    
    AS = [0 for i in range(0,imax+1)]
    flag = 1
    
    # ----------------------------------------
    # Step 1
    # ----------------------------------------
    
    # set status of all nodes in Gc as inactive
    set_status_inactive(Gc)
    
    # initial set of active nodes
    AS[0] = Centrality(Gc,p,centrality_measure=centrality_measure)
    
    # set status of AS nodes to active
    set_status_active(Gc,AS[0])
    
    # ----------------------------------------
    # Step 2
    # ----------------------------------------
    for i in range(0,imax+1):
        
        print("-"*50)
        print("Value of i:",i)
        print("-"*50)
        
        print("At start of iteration:",i)
        print(f"Number of active nodes: {count_active(Gc)}/{Gc.number_of_nodes()}, {(count_active(Gc)/Gc.number_of_nodes()*100):.2f}% nodes")
        
        PS = [] # pending active set
        for u in Gc.nodes():
            if ((Gc.nodes[u]['status'] == "inactive") and (u not in PS)):
                score = peer_influence(Gc,u)
                if score > Gc.nodes[u]['threshold']:
                    PS.append(u)

        if i < imax: 
          AS[i+1] = AS[i] + PS
          AS[i+1] = list(set(sorted(AS[i+1])))
          
          if AS[i+1] == AS[i]:
              print("Converged at iteration:",i)
              flag = 0
              break
          
          set_status_active(Gc,AS[i+1])
          print(f"Number of active nodes: {count_active(Gc)}/{Gc.number_of_nodes()}, {(count_active(Gc)/Gc.number_of_nodes()*100):.2f}% nodes")
    
    if flag:
        print("Converged at iteration:",imax)

# %% [markdown]
# # Centrality Measures

# %% [markdown]
# # Degree Centrality

# %%
G2 = create_graph(data_vil2)
set_status_inactive(G2)
set_threshold(G2)
gt_model(G2,p=10,imax=10,centrality_measure="degree")
# Out:
# --------------------------------------------------
# Value of i: 0
# --------------------------------------------------
# At start of iteration: 0
# Number of active nodes: 10/604, 1.66% nodes
# Number of active nodes: 33/604, 5.46% nodes
# --------------------------------------------------
# Value of i: 1
# --------------------------------------------------
# At start of iteration: 1
# Number of active nodes: 33/604, 5.46% nodes
# Number of active nodes: 53/604, 8.77% nodes
# --------------------------------------------------
# Value of i: 2
# --------------------------------------------------
# At start of iteration: 2
# Number of active nodes: 53/604, 8.77% nodes
# Number of active nodes: 77/604, 12.75% nodes
# --------------------------------------------------
# Value of i: 3
# --------------------------------------------------
# At start of iteration: 3
# Number of active nodes: 77/604, 12.75% nodes
# Number of active nodes: 93/604, 15.40% nodes
# --------------------------------------------------
# Value of i: 4
# --------------------------------------------------
# At start of iteration: 4
# Number of active nodes: 93/604, 15.40% nodes
# Number of active nodes: 104/604, 17.22% nodes
# --------------------------------------------------
# Value of i: 5
# --------------------------------------------------
# At start of iteration: 5
# Number of active nodes: 104/604, 17.22% nodes
# Number of active nodes: 111/604, 18.38% nodes
# --------------------------------------------------
# Value of i: 6
# --------------------------------------------------
# At start of iteration: 6
# Number of active nodes: 111/604, 18.38% nodes
# Number of active nodes: 117/604, 19.37% nodes
# --------------------------------------------------
# Value of i: 7
# --------------------------------------------------
# At start of iteration: 7
# Number of active nodes: 117/604, 19.37% nodes
# Number of active nodes: 121/604, 20.03% nodes
# --------------------------------------------------
# Value of i: 8
# --------------------------------------------------
# At start of iteration: 8
# Number of active nodes: 121/604, 20.03% nodes
# Converged at iteration: 8

# %% [markdown]
# # Closeness Centrality

# %%
G2 = create_graph(data_vil2)
set_status_inactive(G2)
set_threshold(G2)
gt_model(G2,p=10,imax=10,centrality_measure="closeness")
# Out:
# --------------------------------------------------
# Value of i: 0
# --------------------------------------------------
# At start of iteration: 0
# Number of active nodes: 10/604, 1.66% nodes
# Number of active nodes: 29/604, 4.80% nodes
# --------------------------------------------------
# Value of i: 1
# --------------------------------------------------
# At start of iteration: 1
# Number of active nodes: 29/604, 4.80% nodes
# Number of active nodes: 43/604, 7.12% nodes
# --------------------------------------------------
# Value of i: 2
# --------------------------------------------------
# At start of iteration: 2
# Number of active nodes: 43/604, 7.12% nodes
# Number of active nodes: 58/604, 9.60% nodes
# --------------------------------------------------
# Value of i: 3
# --------------------------------------------------
# At start of iteration: 3
# Number of active nodes: 58/604, 9.60% nodes
# Number of active nodes: 72/604, 11.92% nodes
# --------------------------------------------------
# Value of i: 4
# --------------------------------------------------
# At start of iteration: 4
# Number of active nodes: 72/604, 11.92% nodes
# Number of active nodes: 77/604, 12.75% nodes
# --------------------------------------------------
# Value of i: 5
# --------------------------------------------------
# At start of iteration: 5
# Number of active nodes: 77/604, 12.75% nodes
# Number of active nodes: 84/604, 13.91% nodes
# --------------------------------------------------
# Value of i: 6
# --------------------------------------------------
# At start of iteration: 6
# Number of active nodes: 84/604, 13.91% nodes
# Number of active nodes: 95/604, 15.73% nodes
# --------------------------------------------------
# Value of i: 7
# --------------------------------------------------
# At start of iteration: 7
# Number of active nodes: 95/604, 15.73% nodes
# Number of active nodes: 103/604, 17.05% nodes
# --------------------------------------------------
# Value of i: 8
# --------------------------------------------------
# At start of iteration: 8
# Number of active nodes: 103/604, 17.05% nodes
# Number of active nodes: 111/604, 18.38% nodes
# --------------------------------------------------
# Value of i: 9
# --------------------------------------------------
# At start of iteration: 9
# Number of active nodes: 111/604, 18.38% nodes
# Number of active nodes: 116/604, 19.21% nodes
# --------------------------------------------------
# Value of i: 10
# --------------------------------------------------
# At start of iteration: 10
# Number of active nodes: 116/604, 19.21% nodes
# Converged at iteration: 10

# %% [markdown]
# # Betweeness Centrality

# %%
G2 = create_graph(data_vil2)
set_status_inactive(G2)
set_threshold(G2)
gt_model(G2,p=10,imax=10,centrality_measure="betweeness")
# Out:
# --------------------------------------------------
# Value of i: 0
# --------------------------------------------------
# At start of iteration: 0
# Number of active nodes: 10/604, 1.66% nodes
# Number of active nodes: 36/604, 5.96% nodes
# --------------------------------------------------
# Value of i: 1
# --------------------------------------------------
# At start of iteration: 1
# Number of active nodes: 36/604, 5.96% nodes
# Number of active nodes: 55/604, 9.11% nodes
# --------------------------------------------------
# Value of i: 2
# --------------------------------------------------
# At start of iteration: 2
# Number of active nodes: 55/604, 9.11% nodes
# Number of active nodes: 71/604, 11.75% nodes
# --------------------------------------------------
# Value of i: 3
# --------------------------------------------------
# At start of iteration: 3
# Number of active nodes: 71/604, 11.75% nodes
# Number of active nodes: 77/604, 12.75% nodes
# --------------------------------------------------
# Value of i: 4
# --------------------------------------------------
# At start of iteration: 4
# Number of active nodes: 77/604, 12.75% nodes
# Number of active nodes: 87/604, 14.40% nodes
# --------------------------------------------------
# Value of i: 5
# --------------------------------------------------
# At start of iteration: 5
# Number of active nodes: 87/604, 14.40% nodes
# Number of active nodes: 102/604, 16.89% nodes
# --------------------------------------------------
# Value of i: 6
# --------------------------------------------------
# At start of iteration: 6
# Number of active nodes: 102/604, 16.89% nodes
# Number of active nodes: 110/604, 18.21% nodes
# --------------------------------------------------
# Value of i: 7
# --------------------------------------------------
# At start of iteration: 7
# Number of active nodes: 110/604, 18.21% nodes
# Number of active nodes: 113/604, 18.71% nodes
# --------------------------------------------------
# Value of i: 8
# --------------------------------------------------
# At start of iteration: 8
# Number of active nodes: 113/604, 18.71% nodes
# Number of active nodes: 118/604, 19.54% nodes
# --------------------------------------------------
# Value of i: 9
# --------------------------------------------------
# At start of iteration: 9
# Number of active nodes: 118/604, 19.54% nodes
# Number of active nodes: 120/604, 19.87% nodes
# --------------------------------------------------
# Value of i: 10
# --------------------------------------------------
# At start of iteration: 10
# Number of active nodes: 120/604, 19.87% nodes
# Converged at iteration: 10

# %% [markdown]
# # PageRank

# %%
G2 = create_graph(data_vil2)
set_status_inactive(G2)
set_threshold(G2)
gt_model(G2,p=10,imax=10,centrality_measure="pagerank")
# Out:
# --------------------------------------------------
# Value of i: 0
# --------------------------------------------------
# At start of iteration: 0
# Number of active nodes: 10/604, 1.66% nodes
# Number of active nodes: 33/604, 5.46% nodes
# --------------------------------------------------
# Value of i: 1
# --------------------------------------------------
# At start of iteration: 1
# Number of active nodes: 33/604, 5.46% nodes
# Number of active nodes: 51/604, 8.44% nodes
# --------------------------------------------------
# Value of i: 2
# --------------------------------------------------
# At start of iteration: 2
# Number of active nodes: 51/604, 8.44% nodes
# Number of active nodes: 76/604, 12.58% nodes
# --------------------------------------------------
# Value of i: 3
# --------------------------------------------------
# At start of iteration: 3
# Number of active nodes: 76/604, 12.58% nodes
# Number of active nodes: 93/604, 15.40% nodes
# --------------------------------------------------
# Value of i: 4
# --------------------------------------------------
# At start of iteration: 4
# Number of active nodes: 93/604, 15.40% nodes
# Number of active nodes: 104/604, 17.22% nodes
# --------------------------------------------------
# Value of i: 5
# --------------------------------------------------
# At start of iteration: 5
# Number of active nodes: 104/604, 17.22% nodes
# Number of active nodes: 115/604, 19.04% nodes
# --------------------------------------------------
# Value of i: 6
# --------------------------------------------------
# At start of iteration: 6
# Number of active nodes: 115/604, 19.04% nodes
# Number of active nodes: 122/604, 20.20% nodes
# --------------------------------------------------
# Value of i: 7
# --------------------------------------------------
# At start of iteration: 7
# Number of active nodes: 122/604, 20.20% nodes
# Number of active nodes: 126/604, 20.86% nodes
# --------------------------------------------------
# Value of i: 8
# --------------------------------------------------
# At start of iteration: 8
# Number of active nodes: 126/604, 20.86% nodes
# Converged at iteration: 8

# %% [markdown]
# # Katz

# %%
G2 = create_graph(data_vil2)
set_status_inactive(G2)
set_threshold(G2)
gt_model(G2,p=10,imax=10,centrality_measure="katz")
# Out:
# ---------------------------------------------------------------------------
# PowerIterationFailedConvergence           Traceback (most recent call last)
# <ipython-input-19-555110df8472> in <module>()
#       2 set_status_inactive(G2)
#       3 set_threshold(G2)
# ----> 4 gt_model(G2,p=10,imax=10,centrality_measure="katz")
#
# <ipython-input-18-44247d4651d2> in gt_model(Gc, p, imax, centrality_measure)
#     115
#     116     # initial set of active nodes
# --> 117     AS[0] = Centrality(Gc,p,centrality_measure=centrality_measure)
#     118
#     119     # set status of AS nodes to active
#
# <ipython-input-18-44247d4651d2> in Centrality(Gc, p, centrality_measure)
#      93             pr = nx.pagerank(Gc)
#      94         elif centrality_measure == "katz":
# ---> 95             pr = nx.katz_centrality(Gc, 0.07,max_iter=50000)
#      96         n = Gc.number_of_nodes()
#      97         n = p
#
# /usr/local/lib/python3.7/dist-packages/networkx/utils/decorators.py in argmap_katz_centrality_6(G, alpha, beta, max_iter, tol, nstart, normalized, weight)
#       2 from os.path import splitext
#       3 from contextlib import contextmanager
# ----> 4 from pathlib import Path
#       5 import warnings
#       6
#
# /usr/local/lib/python3.7/dist-packages/networkx/algorithms/centrality/katz.py in katz_centrality(G, alpha, beta, max_iter, tol, nstart, normalized, weight)
#     191                 x[n] *= s
#     192             return x
# --> 193     raise nx.PowerIterationFailedConvergence(max_iter)
#     194
#     195
#
# PowerIterationFailedConvergence: (PowerIterationFailedConvergence(...), 'power iteration failed to converge within 50000 iterations')
